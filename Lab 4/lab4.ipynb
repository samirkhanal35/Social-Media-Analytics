# %%
api_key = 'AIzaSyAdLWld7ZgEz0P9ZI1HdWOV4_c90eJb0oA'

# %%
# from googleapiclient.discovery import build

# %%
# !pip install google-api-python-client

# %%
from googleapiclient.discovery import build

# %%
# Create a Youtube resource object

myYoutube = build('youtube', 'v3', developerKey=api_key)

# %%
# Retrieve youtube video comments

video_response = myYoutube.commentThreads().list(
    part='snippet, replies',
    videoId='6YKV3zCdUtc'
).execute()

# %%
video_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'el9cH77a3VnZDAxJ3pj8I4DAWOs',
#  'nextPageToken': 'QURTSl9pMjVtLTZJWi14bndVb0VOeUhJeGZqVk55SGFRSzlDNmxlU3QzQmgxWVFYelFKdWxWdHZ5Qk5kUlRFMU1PcVZpYlMyYWNzVmZscw==',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'ThT2vyz-iGNZ-DfebnO1MZv7r-s',
#    'id': 'Ugz91h5wykczNn2KLeh4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RDEk3k6RWJ_6-iX8FSKcq85MHXc',
#      'id': 'Ugz91h5wykczNn2KLeh4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': '🖕🖕🥰🥰',
#       'textOriginal': '🖕🖕🥰🥰',
#       'authorDisplayName': 'Popy Riya',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKYGNAlNlj6Jq41zGqMmKGVJBXm3U9rw4j4_JLTWXwwIdua4j0jrpTAa7zEqN0HI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpTb3Y-aZeXot7VZWXenQTQ',
#       'authorChannelId': {'value': 'UCpTb3Y-aZeXot7VZWXenQTQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-27T10:28:42Z',
#       'updatedAt': '2023-09-27T10:28:42Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A3YV0hdOlDKyVngtSEZFfBrAD3E',
#    'id': 'UgwqPoh_A4jpK9WQayp4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'DiyWFIi0rsdV0senVSQ1fNE_0iY',
#      'id': 'UgwqPoh_A4jpK9WQayp4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'That’s not an mls goal its a tournament goal',
#       'textOriginal': 'That’s not an mls goal its a tournament goal',
#       'authorDisplayName': 'WillVauld',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/IrmOQaMtxGtMxHyID25LS83DnhINQ1vZtePBNA7rNWK8AuyWAEMkJGy-_qTyWQOeA-kDWNXY=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCC0ee0bHqymZXHd7dBNUyqQ',
#       'authorChannelId': {'value': 'UCC0ee0bHqymZXHd7dBNUyqQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-27T00:23:38Z',
#       'updatedAt': '2023-09-27T00:23:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 't4yGN90oQuJ0VrXVbBMwGnHonDc',
#    'id': 'UgxvOoZzdPGSESvBBTZ4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JNa3W9iKbMws86i91yoJRBhOgJ8',
#      'id': 'UgxvOoZzdPGSESvBBTZ4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'hi🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉',
#       'textOriginal': 'hi🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉',
#       'authorDisplayName': 'Anithamol',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKbEeMbF4yaphw8IJ75ZtV2H2g7b0McK2mYuNN83Ktg7emWdQum0HT9MqLQhUNbe=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCLoBslaDQRy0wk6yqJz15ZA',
#       'authorChannelId': {'value': 'UCLoBslaDQRy0wk6yqJz15ZA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-09-26T07:32:03Z',
#       'updatedAt': '2023-09-26T07:32:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'vQwJem2vvuzg3RkjIRqZrksTT0w',
#    'id': 'Ugy971Zf0LGyj6c6xnl4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-kscmOqaK-RTO1o4Q4e96pa83g0',
#      'id': 'Ugy971Zf0LGyj6c6xnl4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'MESSİ GOALLL',
#       'textOriginal': 'MESSİ GOALLL',
#       'authorDisplayName': 'Berat Beşiktaş',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/dzvsKkiANDeGHHe3eOIGLr6GsZOHOpSxmm2itCWZTgQnH_v00TAJf_JExtkeyy-QRurEcFmB=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCXeIR3jZ4nak5nlzn3bQvEw',
#       'authorChannelId': {'value': 'UCXeIR3jZ4nak5nlzn3bQvEw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-25T15:31:15Z',
#       'updatedAt': '2023-09-25T15:31:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'XrLzfFn_bQxTU3d-jVNsax9YkRw',
#    'id': 'UgzXVSBhfXsIIaRhE-14AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Dm87H21EXUs6Gt1GQ3LLboRd8T8',
#      'id': 'UgzXVSBhfXsIIaRhE-14AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'That is the Ligues Cup, not MLS 😳',
#       'textOriginal': 'That is the Ligues Cup, not MLS 😳',
#       'authorDisplayName': 'Ulises Ortega Aragón',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKbN5qQ_WE-cq8jPKcaRoRLLIhhRrpm8tDvO7ZgjXDE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCneMF7ZopBoqMNW0apo15iA',
#       'authorChannelId': {'value': 'UCneMF7ZopBoqMNW0apo15iA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-25T08:39:56Z',
#       'updatedAt': '2023-09-25T08:39:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PFTk-x2DJ4zSQoY9bwVBv3qmCyM',
#    'id': 'UgzU9QBhx5XghiG102p4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'beYxky8sP_DjybmyuMI1WMhABQ8',
#      'id': 'UgzU9QBhx5XghiG102p4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Le meilleur joueur du monde',
#       'textOriginal': 'Le meilleur joueur du monde',
#       'authorDisplayName': 'samba Hadietou',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKaRWi6CPrPYHCbzhS5qfrV32mvgx7MX0c0afus1_gfwSznvhz6MrIzYNsvWiVwF=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCdaZXBGtrH0WR4dkQNU7_sQ',
#       'authorChannelId': {'value': 'UCdaZXBGtrH0WR4dkQNU7_sQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-24T16:55:40Z',
#       'updatedAt': '2023-09-24T16:55:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'A6qhCBYMj1m4Wu0siP2cc9tID0M',
#    'id': 'Ugzz64s9b3PwQcLZVch4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RgsXUQbzt_H0VlD1e4Ws_TY8LaE',
#      'id': 'Ugzz64s9b3PwQcLZVch4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Uehshshsjshsgqg🎉❤',
#       'textOriginal': 'Uehshshsjshsgqg🎉❤',
#       'authorDisplayName': 'Jonatan Godoy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKbY96vYnsWpUIJabkaczHjILnUDW55--GfjrQum6Bi1V2UnK7-6E4LUui8TUXwT=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcmqpERaWDoE3ItG61bi1og',
#       'authorChannelId': {'value': 'UCcmqpERaWDoE3ItG61bi1og'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-23T13:41:30Z',
#       'updatedAt': '2023-09-23T13:41:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ZiSPJIOAvKPnkRtY-Ht45hVvWHI',
#    'id': 'UgzoiR2Se9NKl8vPbfF4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zmQH5mM_1DBmGHfhm33Nu0b0oek',
#      'id': 'UgzoiR2Se9NKl8vPbfF4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': '❤❤❤❤❤😊😊',
#       'textOriginal': '❤❤❤❤❤😊😊',
#       'authorDisplayName': 'Hajizada Samir',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZ3KsPnJrk24IBiDf9vMeGpBP8bMbUlUso1IpeyU-sry3xqXXOAb5xmvQ450qoO=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCVWzu5vo34gmg8_UvWzWcrg',
#       'authorChannelId': {'value': 'UCVWzu5vo34gmg8_UvWzWcrg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-23T11:00:43Z',
#       'updatedAt': '2023-09-23T11:00:43Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LoC1LLyyd8YV944c6wkQ3WJTzdk',
#    'id': 'Ugx0DBjcoc1us36-meN4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Twy4bxtkGitbM4i9aCBvKu-JCuo',
#      'id': 'Ugx0DBjcoc1us36-meN4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Wow!!! Just wow!!! <br>            <br>                  -Gol D Roger',
#       'textOriginal': 'Wow!!! Just wow!!! \n            \n                  -Gol D Roger',
#       'authorDisplayName': "i'm orange",
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZkAPRHzjWNHfOOSXBczTwJxe8nCTHzV-cj6Kfm=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCuz35slVkpvvVJl2RjCz1hA',
#       'authorChannelId': {'value': 'UCuz35slVkpvvVJl2RjCz1hA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-23T09:44:20Z',
#       'updatedAt': '2023-09-23T09:44:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xsFg3ezqHHLsl6EZIn5B5YqGqDc',
#    'id': 'UgxgY6CqAbk_cAcuq5J4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'cqbpN9gb1mNGQjd7rWE2Dwjs5g8',
#      'id': 'UgxgY6CqAbk_cAcuq5J4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': '🤯😱',
#       'textOriginal': '🤯😱',
#       'authorDisplayName': 'Aung Myint Mo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKayZGE_hKph2OWOeqIVdTJHIPoH5U8L2-PYh1kWJGZ9kYVfuaBZnv4_3v8RFlZG=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpvJfrnf9Z3Op19i-xPzOrg',
#       'authorChannelId': {'value': 'UCpvJfrnf9Z3Op19i-xPzOrg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-22T06:36:05Z',
#       'updatedAt': '2023-09-22T06:36:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '3TOhkBCtQ2CMyhhFz3-87FO-kv8',
#    'id': 'UgwaS7Kz9LgG_CoMfbl4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2PFOpeCo__Hs2i5IaTgvgPyWd4I',
#      'id': 'UgwaS7Kz9LgG_CoMfbl4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Messi❤',
#       'textOriginal': 'Messi❤',
#       'authorDisplayName': 'Md Kalu',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/sAoVaNPwH8Oln-gPRwtP6Ap_P2uaWQMYExW1FgL7ZqFNn7vWpxiLyTk9FzljAgqCUSXu9zek=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCGJhUd8ni0EDOmMOIO8RmcQ',
#       'authorChannelId': {'value': 'UCGJhUd8ni0EDOmMOIO8RmcQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2023-09-22T03:32:19Z',
#       'updatedAt': '2023-09-22T03:32:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'XMki5wczutyLO3PW-i0j_V5S4c4',
#    'id': 'UgyEXgz2cHKWP97CGkV4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6RIlbJz9e2rTJNjp-MG_FA1Y-2g',
#      'id': 'UgyEXgz2cHKWP97CGkV4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Messi score a normal goal:<br>Amazing<br>Goated<br>What a goal<br><br>Ronaldo score a amazing goal:<br>Lucky goal<br>He think he is goat<br>Trashy!!<br><br>😢',
#       'textOriginal': 'Messi score a normal goal:\nAmazing\nGoated\nWhat a goal\n\nRonaldo score a amazing goal:\nLucky goal\nHe think he is goat\nTrashy!!\n\n😢',
#       'authorDisplayName': 'SUVs_edit--&',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Y1HIzDZvzJTCK-MTDlpaXs0PGP5t5_7EzS1317PJN6eIRA6h9AWvp2L1GbgLtMn_wu4yGXRc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCWhxwL4-MVJeBSSf3GNt1AQ',
#       'authorChannelId': {'value': 'UCWhxwL4-MVJeBSSf3GNt1AQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-20T15:18:14Z',
#       'updatedAt': '2023-09-20T15:18:14Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'eeqMb6fjyyGOBWMchp_ZRkMKrvk',
#    'id': 'UgyYDRZJxc82Xxq5nAd4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MPcQ00-Oq2fzxuVrFsIur8bdnqE',
#      'id': 'UgyYDRZJxc82Xxq5nAd4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Pessi pessi ronaldo 🐐 Messi thrash',
#       'textOriginal': 'Pessi pessi ronaldo 🐐 Messi thrash',
#       'authorDisplayName': 'Miss Suleman',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKahjtCHptjt4atfQFCD7ooft1F_a0ReI-d8hxCRiKBV6iScT3MwVrKuMdBtY8td=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC07mD_Xf8r7715mkuoj930w',
#       'authorChannelId': {'value': 'UC07mD_Xf8r7715mkuoj930w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-19T07:02:25Z',
#       'updatedAt': '2023-09-19T07:02:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hJuEDrA0wxtutddkzvfmrBtbI9k',
#    'id': 'Ugx1__aXn2boxpou9zB4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GIcQDy3oTbvufB0nBq78Mm5LhFc',
#      'id': 'Ugx1__aXn2boxpou9zB4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'que grande es un genio sin lugar a dudas el MEJOR CON MAYÚSCULAS ❤',
#       'textOriginal': 'que grande es un genio sin lugar a dudas el MEJOR CON MAYÚSCULAS ❤',
#       'authorDisplayName': 'Eva Marzano',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKYPG3ClsKuWmsXf2IWKqiuRE5Q8P-MP7Yri9g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgIcLINMPCW4P_-yjY0uIXA',
#       'authorChannelId': {'value': 'UCgIcLINMPCW4P_-yjY0uIXA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-19T01:08:57Z',
#       'updatedAt': '2023-09-19T01:08:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'AOFRWv5ljZaNUP_7eyg08Q-v5fk',
#    'id': 'Ugx3ONGdQ4AcXung6HJ4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'TnTB6hldILxB-M2l5ZkZovWR1Ko',
#      'id': 'Ugx3ONGdQ4AcXung6HJ4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'I grew up on Pele, Cruyff, Meridona but NO ONE COMPARES TO MESSI',
#       'textOriginal': 'I grew up on Pele, Cruyff, Meridona but NO ONE COMPARES TO MESSI',
#       'authorDisplayName': 'john oneill',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZXmKfftIXMABBqGPSN5suIhrPF1wlF02sk3g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1XZS6U8pNToLJ3IAyNIy2A',
#       'authorChannelId': {'value': 'UC1XZS6U8pNToLJ3IAyNIy2A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-18T22:38:15Z',
#       'updatedAt': '2023-09-18T22:38:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7CwB4w5x0NK6fRd8oqfYgsWcxqU',
#    'id': 'UgxhVJgSRFUY8MSsEuR4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'sHXgw-GAwAKND60inuZ9eHF8SQs',
#      'id': 'UgxhVJgSRFUY8MSsEuR4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Goat',
#       'textOriginal': 'Goat',
#       'authorDisplayName': 'Football geniuses',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/C1JaiOznNviJ02Zv0Owr7bhVfkmjXTeuFzuQq93QOdhvBk0xKiqad_e7Bgc395JA2t9ShRokuXs=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCs2YRJzrNWHxgRJmbLZiWPA',
#       'authorChannelId': {'value': 'UCs2YRJzrNWHxgRJmbLZiWPA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-16T23:57:36Z',
#       'updatedAt': '2023-09-16T23:57:36Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'sGiWL6kBFmX9w5BDdammrUbQILw',
#    'id': 'UgwgJ5LJIJOiJgknkL54AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2-8sc0EJkFtbMfUGq9Wu2v-6kLw',
#      'id': 'UgwgJ5LJIJOiJgknkL54AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Il vorien',
#       'textOriginal': 'Il vorien',
#       'authorDisplayName': 'kouakou arie',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/1CLcOqv76kvJyCvlRHYQYpi__Cta3O6gUFlcnfrYV0TFh3br2wNcUdXfA1mHpb4hw_zBFUVw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCF3HV9h9V4HqDiUhE3sIryw',
#       'authorChannelId': {'value': 'UCF3HV9h9V4HqDiUhE3sIryw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-16T17:46:10Z',
#       'updatedAt': '2023-09-16T17:46:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Hm6khdddwhCzOWGaJd8on5fRKJ8',
#    'id': 'UgyUOk5SfYkUWdYiSXF4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6TFXaA4df8FDeMMvZLslb-Ex3xg',
#      'id': 'UgyUOk5SfYkUWdYiSXF4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': '😂😂😂😂😂mggijlgcb',
#       'textOriginal': '😂😂😂😂😂mggijlgcb',
#       'authorDisplayName': 'Ali Romzan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKZoG-gFrmo65_s_wsozdBegJlpGe2cyVWBanqwyY6XJjBIyXEjEo-tsXZpTAb2w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgJb8t4Xex73kzQPKjAb6tg',
#       'authorChannelId': {'value': 'UCgJb8t4Xex73kzQPKjAb6tg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-15T08:32:25Z',
#       'updatedAt': '2023-09-15T08:32:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'j_wacYepTWiQZjMvdMYJKuZG7ns',
#    'id': 'UgzUY2kbwoIde6COcct4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ZLeRdlMre0TrfCCZYjKCa2ZqD-Q',
#      'id': 'UgzUY2kbwoIde6COcct4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': 'Dude it&#39;s not his first goal from the mls',
#       'textOriginal': "Dude it's not his first goal from the mls",
#       'authorDisplayName': 'More MamothMcfatfan5125',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/s5IyB824bZjU5hjRT6o_oBVVaqypqikfMpl1oMHzUxCQvksUA-xQvPz8hdNI6DqF2Enxr2m9HQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCZiD-IDWU3hjXTtba1J9ZTA',
#       'authorChannelId': {'value': 'UCZiD-IDWU3hjXTtba1J9ZTA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-11T06:36:28Z',
#       'updatedAt': '2023-09-11T06:36:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '1oZn6WfWQe4f3Mu5briBGFnyw_w',
#    'id': 'UgyAILjAEmCCgm8BLNl4AaABAg',
#    'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#     'videoId': '6YKV3zCdUtc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'qRiDVMOKYVtEWOmdmAfyOIWYyAk',
#      'id': 'UgyAILjAEmCCgm8BLNl4AaABAg',
#      'snippet': {'channelId': 'UC6c1z7bA__85CIWZ_jpCK-Q',
#       'videoId': '6YKV3zCdUtc',
#       'textDisplay': '❤❤❤❤❤😊😊😊',
#       'textOriginal': '❤❤❤❤❤😊😊😊',
#       'authorDisplayName': 'Sunni Begam',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/APkrFKafc7aKp4RU0kQyXKAScqVDn6txvyqkmgzj0KqDNLadeGIgzzvW8itbQHJQCE7B=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC0UETu185I2MIp3SDayUb3Q',
#       'authorChannelId': {'value': 'UC0UETu185I2MIp3SDayUb3Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2023-09-11T03:55:24Z',
#       'updatedAt': '2023-09-11T03:55:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
len(video_response)
# Out:
# 5

# %%
# Irerate over Youtube comments
count = 0
for item in video_response['items']:
    count += 1
    print("Comment:", count, ":")
    # Extract the comment
    comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
    print(comment)
# Out:
# Comment: 1 :
# 🖕🖕🥰🥰
# Comment: 2 :
# That’s not an mls goal its a tournament goal
# Comment: 3 :
# hi🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉
# Comment: 4 :
# MESSİ GOALLL
# Comment: 5 :
# That is the Ligues Cup, not MLS 😳
# Comment: 6 :
# Le meilleur joueur du monde
# Comment: 7 :
# Uehshshsjshsgqg🎉❤
# Comment: 8 :
# ❤❤❤❤❤😊😊
# Comment: 9 :
# Wow!!! Just wow!!! <br>            <br>                  -Gol D Roger
# Comment: 10 :
# 🤯😱
# Comment: 11 :
# Messi❤
# Comment: 12 :
# Messi score a normal goal:<br>Amazing<br>Goated<br>What a goal<br><br>Ronaldo score a amazing goal:<br>Lucky goal<br>He think he is goat<br>Trashy!!<br><br>😢
# Comment: 13 :
# Pessi pessi ronaldo 🐐 Messi thrash
# Comment: 14 :
# que grande es un genio sin lugar a dudas el MEJOR CON MAYÚSCULAS ❤
# Comment: 15 :
# I grew up on Pele, Cruyff, Meridona but NO ONE COMPARES TO MESSI
# Comment: 16 :
# Goat
# Comment: 17 :
# Il vorien
# Comment: 18 :
# 😂😂😂😂😂mggijlgcb
# Comment: 19 :
# Dude it&#39;s not his first goal from the mls
# Comment: 20 :
# ❤❤❤❤❤😊😊😊

# %%
count
# Out:
# 20

# %%
# more than 20 comments 
# impage and id of the persons
#
